# %% [markdown]
# # Probe Analysis
#
# Minimal notebook for probing batches of points and analyzing the returned arrays directly.

# %%
from pathlib import Path
import sys

import matplotlib.pyplot as plt
import numpy as np

root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(root))

from client.config import registry
from client.interface import SlopClient

print(registry.list())
# Out:
# [ProviderConfig(name='vast-32582479', kind='ssh', target='vast-32582479', remote_path='/root/slop', python_cmd='python3', container_image=None, num_workers=8)]

# %%
providers = registry.list()
assert providers, 'no providers registered'
cfg = providers[-1]
client = SlopClient(cfg)
client.connect()
# Out:
# [REMOTE STDERR] Welcome to vast.ai. If authentication fails, try again after a few seconds, and double check your ssh key.
# [REMOTE STDERR] Have fun!
# [REMOTE STDERR] [SERVER] 2026-03-09 14:10:58,704 - INFO - server ready

# %%
points = np.random.randn(4, 4, 64, 64).astype(np.float32)
delta = client.probe_delta(points, prompt_a='a person', prompt_b='a warrior', timestep=5)
delta.shape
# Out:
# [REMOTE STDERR] [SERVER] 2026-03-09 14:11:55,434 - INFO - sample/probe request model=runwayml/stable-diffusion-v1-5
# [REMOTE STDERR] [SERVER] 2026-03-09 14:11:55,940 - ERROR - request failed: CUDA out of memory. Tried to allocate 160.00 MiB. GPU 0 has a total capacity of 23.56 GiB of which 6.00 MiB is free. Including non-PyTorch memory, this process has 23.54 GiB memory in use. Of the allocated memory 23.12 GiB is allocated by PyTorch, and 111.06 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# [REMOTE STDERR] Traceback (most recent call last):
# [REMOTE STDERR] File "/root/slop/server/daemon.py", line 60, in process_request
# [REMOTE STDERR] return self.runner.run(req)
# [REMOTE STDERR] ^^^^^^^^^^^^^^^^^^^^
# [REMOTE STDERR] File "/root/slop/server/inference/runner.py", line 243, in run
# [REMOTE STDERR] return self._run_probe(req)
# [REMOTE STDERR] ^^^^^^^^^^^^^^^^^^^^
# [REMOTE STDERR] File "/root/slop/server/inference/runner.py", line 147, in _run_probe
# [REMOTE STDERR] base_forces = score(self.pipe, points, timestep, base_prompt_embeds, base_negative_prompt_embeds, req.guidance_scale)
# [REMOTE STDERR] ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [REMOTE STDERR] File "/root/slop/server/inference/primitives.py", line 99, in score
# [REMOTE STDERR] model_out = pipe.unet(latent_input, timestep, encoder_hidden_states=embeds).sample
# [REMOTE STDERR] ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [REMOTE STDERR] File "/opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
# [REMOTE STDERR] return self._call_impl(*args, **kwargs)
# [REMOTE STDERR] ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [REMOTE STDERR] File "/opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1787, in _call_impl
# [REMOTE STDERR] return forward_call(*args, **kwargs)
# [REMOTE STDERR] ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [REMOTE STDERR] File "/opt/conda/lib/python3.11/site-packages/diffusers/models/unets/unet_2d_condition.py", line 1281, in forward
# [REMOTE STDERR] sample = upsample_block(
# [REMOTE STDERR] ^^^^^^^^^^^^^^^
# [REMOTE STDERR] File "/opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
# [REMOTE STDERR] return self._call_impl(*args, **kwargs)
# [REMOTE STDERR] ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [REMOTE STDERR] File "/opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1787, in _call_impl
# [REMOTE STDERR] return forward_call(*args, **kwargs)
# [REMOTE STDERR] ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [REMOTE STDERR] File "/opt/conda/lib/python3.11/site-packages/diffusers/models/unets/unet_2d_blocks.py", line 2551, in forward
# [REMOTE STDERR] hidden_states = attn(
# [REMOTE STDERR] ^^^^^
# [REMOTE STDERR] File "/opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
# [REMOTE STDERR] return self._call_impl(*args, **kwargs)
# [REMOTE STDERR] ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [REMOTE STDERR] File "/opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1787, in _call_impl
# [REMOTE STDERR] return forward_call(*args, **kwargs)
# [REMOTE STDERR] ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [REMOTE STDERR] File "/opt/conda/lib/python3.11/site-packages/diffusers/models/transformers/transformer_2d.py", line 442, in forward
# [REMOTE STDERR] hidden_states = block(
# [REMOTE STDERR] ^^^^^^
# [REMOTE STDERR] File "/opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
# [REMOTE STDERR] return self._call_impl(*args, **kwargs)
# [REMOTE STDERR] ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [REMOTE STDERR] File "/opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1787, in _call_impl
# [REMOTE STDERR] return forward_call(*args, **kwargs)
# [REMOTE STDERR] ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [REMOTE STDERR] File "/opt/conda/lib/python3.11/site-packages/diffusers/models/attention.py", line 571, in forward
# [REMOTE STDERR] ff_output = self.ff(norm_hidden_states)
# [REMOTE STDERR] ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [REMOTE STDERR] File "/opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
# [REMOTE STDERR] return self._call_impl(*args, **kwargs)
# [REMOTE STDERR] ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [REMOTE STDERR] File "/opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1787, in _call_impl
# [REMOTE STDERR] return forward_call(*args, **kwargs)
# [REMOTE STDERR] ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [REMOTE STDERR] File "/opt/conda/lib/python3.11/site-packages/diffusers/models/attention.py", line 1242, in forward
# [REMOTE STDERR] hidden_states = module(hidden_states)
# [REMOTE STDERR] ^^^^^^^^^^^^^^^^^^^^^
# [REMOTE STDERR] File "/opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
# [REMOTE STDERR] return self._call_impl(*args, **kwargs)
# [REMOTE STDERR] ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [REMOTE STDERR] File "/opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1787, in _call_impl
# [REMOTE STDERR] return forward_call(*args, **kwargs)
# [REMOTE STDERR] ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [REMOTE STDERR] File "/opt/conda/lib/python3.11/site-packages/diffusers/models/activations.py", line 117, in forward
# [REMOTE STDERR] hidden_states = self.proj(hidden_states)
# [REMOTE STDERR] ^^^^^^^^^^^^^^^^^^^^^^^^
# [REMOTE STDERR] File "/opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
# [REMOTE STDERR] return self._call_impl(*args, **kwargs)
# [REMOTE STDERR] ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [REMOTE STDERR] File "/opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1787, in _call_impl
# [REMOTE STDERR] return forward_call(*args, **kwargs)
# [REMOTE STDERR] ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [REMOTE STDERR] File "/opt/conda/lib/python3.11/site-packages/torch/nn/modules/linear.py", line 134, in forward
# [REMOTE STDERR] return F.linear(input, self.weight, self.bias)
# [REMOTE STDERR] ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# [REMOTE STDERR] torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 160.00 MiB. GPU 0 has a total capacity of 23.56 GiB of which 6.00 MiB is free. Including non-PyTorch memory, this process has 23.54 GiB memory in use. Of the allocated memory 23.12 GiB is allocated by PyTorch, and 111.06 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 2
#       1 points = np.random.randn(8, 4, 64, 64).astype(np.float32)
# ----> 2 delta = client.probe_delta(points, prompt_a='a person', prompt_b='a warrior', timestep=5)
#       3 delta.shape
#
# File ~/code/slop/client/interface.py:346, in SlopClient.probe_delta(self, points, prompt_a, prompt_b, negative_prompt, timestep, guidance_scale, model_id)
#     334 def probe_delta(
#     335     self,
#     336     points: np.ndarray,
#    (...)    343     model_id: str = "runwayml/stable-diffusion-v1-5",
#     344 ) -> np.ndarray:
#     345     """Return one batched delta probe from two prompts."""
# --> 346     job = self._job(
#     347         _probe_request(
#     348             model_id=model_id,
#     349             points=points,
#     350             timestep=timestep,
#     351             guidance_scale=guidance_scale,
#     352             prompt=prompt_b,
#     353             negative_prompt=negative_prompt,
#     354             base_prompt=prompt_a,
#     355             delta_probe=True,
#     356         )
#     357     )
#     358     return unpack_array(job.arrays["delta_noise_preds"])
#
# File ~/code/slop/client/interface.py:128, in SlopClient._job(self, req)
#     126 resp = self.transport.send_request(req)
#     127 if isinstance(resp, ErrorResponse):
# --> 128     raise RuntimeError(resp.error if not resp.traceback else f"{resp.error}\n{resp.traceback}")
#     129 if not isinstance(resp, JobResult):
#     130     raise RuntimeError(f"unexpected response: {type(resp)}")
#
# RuntimeError: CUDA out of memory. Tried to allocate 160.00 MiB. GPU 0 has a total capacity of 23.56 GiB of which 6.00 MiB is free. Including non-PyTorch memory, this process has 23.54 GiB memory in use. Of the allocated memory 23.12 GiB is allocated by PyTorch, and 111.06 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# Traceback (most recent call last):
#   File "/root/slop/server/daemon.py", line 60, in process_request
#     return self.runner.run(req)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/root/slop/server/inference/runner.py", line 243, in run
#     return self._run_probe(req)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/root/slop/server/inference/runner.py", line 147, in _run_probe
#     base_forces = score(self.pipe, points, timestep, base_prompt_embeds, base_negative_prompt_embeds, req.guidance_scale)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/slop/server/inference/primitives.py", line 99, in score
#     model_out = pipe.unet(latent_input, timestep, encoder_hidden_states=embeds).sample
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/diffusers/models/unets/unet_2d_condition.py", line 1281, in forward
#     sample = upsample_block(
#              ^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/diffusers/models/unets/unet_2d_blocks.py", line 2551, in forward
#     hidden_states = attn(
#                     ^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/diffusers/models/transformers/transformer_2d.py", line 442, in forward
#     hidden_states = block(
#                     ^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/diffusers/models/attention.py", line 571, in forward
#     ff_output = self.ff(norm_hidden_states)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/diffusers/models/attention.py", line 1242, in forward
#     hidden_states = module(hidden_states)
#                     ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/diffusers/models/activations.py", line 117, in forward
#     hidden_states = self.proj(hidden_states)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/torch/nn/modules/linear.py", line 134, in forward
#     return F.linear(input, self.weight, self.bias)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 160.00 MiB. GPU 0 has a total capacity of 23.56 GiB of which 6.00 MiB is free. Including non-PyTorch memory, this process has 23.54 GiB memory in use. Of the allocated memory 23.12 GiB is allocated by PyTorch, and 111.06 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
flat = delta.reshape(delta.shape[0], -1)
norms = np.linalg.norm(flat, axis=1)
angles = flat @ flat.mean(axis=0)
norms[:5], angles[:5]

# %%
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.hist(norms, bins=12)
plt.title('Delta Norms')
plt.subplot(1, 2, 2)
plt.hist(angles, bins=12)
plt.title('Projection on Mean Delta')
plt.tight_layout()
plt.show()

# %%
client.close()
